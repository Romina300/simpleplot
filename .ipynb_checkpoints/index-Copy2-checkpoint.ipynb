# %%
import os, geopandas as gpd

countries=gpd.read_file(os.path.join("maps","World_Countries","World_Countries.shp"))
rivers=gpd.read_file(os.path.join("maps","World_Hydrography","World_Hydrography.shp"))
cities=gpd.read_file(os.path.join("maps","World_Cities","World_Cities.shp"))

# %%
countries.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
rivers.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
cities.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
argentina=countries[countries.COUNTRY=='Argentina']

argentina.plot()
# Out:
# <Axes: >

# %%
ciudades_argentina=cities[cities.COUNTRY=='Argentina']

ciudades_argentina.plot()
# Out:
# <Axes: >

# %%
rios_argentina=gpd.clip(gdf=rivers, mask=argentina)

rios_argentina.plot()
# Out:
# <Axes: >

# %%
argentina_coordenada=[-34.61315, -58.37723]

# %%
argentina.to_crs(9252).crs.axis_info
# Out:
# [Axis(name=Northing, abbrev=X, direction=north, unit_auth_code=EPSG, unit_code=9001, unit_name=metre),
#  Axis(name=Easting, abbrev=Y, direction=east, unit_auth_code=EPSG, unit_code=9001, unit_name=metre)]

# %%
argentina.to_crs(9252).plot()
# Out:
# <Axes: >

# %%
mapabase4839=argentina.to_crs(9252).plot()

#alemania.to_crs(4839).centroid.plot(color='pink',ax=mapabase4839)

# %%
argentina9252=argentina.to_crs(9252)
ciudades_argentina=cities[cities.COUNTRY=='Argentina']
ciudades9252=ciudades_argentina.to_crs(argentina9252.crs)#que estas ciudaes se representen dentro del mapa como coordenadas

ciudades9252.plot()
# Out:
# <Axes: >

# %%
rios9252=rivers.to_crs(argentina9252.crs)
rios9252=gpd.clip(gdf=rios9252, mask=argentina9252)

rios9252.plot()
# Out:
# ---------------------------------------------------------------------------
# GEOSException                             Traceback (most recent call last)
# Cell In[41], line 2
#       1 rios9252=rivers.to_crs(argentina9252.crs)
# ----> 2 rios9252=gpd.clip(gdf=rios9252, mask=argentina9252)
#       4 rios9252.plot()
#
# File C:\ProgramData\anaconda3\envs\SDS_Mi_ambiente_Romina\Lib\site-packages\geopandas\tools\clip.py:192, in clip(gdf, mask, keep_geom_type)
#     189 else:
#     190     combined_mask = mask
# --> 192 clipped = _clip_gdf_with_mask(gdf, combined_mask)
#     194 if keep_geom_type:
#     195     geomcoll_concat = (clipped.geom_type == "GeometryCollection").any()
#
# File C:\ProgramData\anaconda3\envs\SDS_Mi_ambiente_Romina\Lib\site-packages\geopandas\tools\clip.py:50, in _clip_gdf_with_mask(gdf, mask)
#      47 else:
#      48     intersection_polygon = mask
# ---> 50 gdf_sub = gdf.iloc[gdf.sindex.query(intersection_polygon, predicate="intersects")]
#      52 # For performance reasons points don't need to be intersected with poly
#      53 non_point_mask = gdf_sub.geom_type != "Point"
#
# File C:\ProgramData\anaconda3\envs\SDS_Mi_ambiente_Romina\Lib\site-packages\geopandas\sindex.py:779, in PyGEOSSTRTreeIndex.query(self, geometry, predicate, sort)
#     776 geometry = self._as_geometry_array(geometry)
#     778 if compat.USE_SHAPELY_20:
# --> 779     indices = self._tree.query(geometry, predicate=predicate)
#     780 else:
#     781     if isinstance(geometry, np.ndarray):
#
# File C:\ProgramData\anaconda3\envs\SDS_Mi_ambiente_Romina\Lib\site-packages\shapely\strtree.py:269, in STRtree.query(self, geometry, predicate, distance)
#     266     return indices[1] if is_scalar else indices
#     268 predicate = BinaryPredicate.get_value(predicate)
# --> 269 indices = self._tree.query(geometry, predicate)
#     270 return indices[1] if is_scalar else indices
#
# GEOSException: IllegalArgumentException: CGAlgorithmsDD::orientationIndex encountered NaN/Inf numbers

# %%
mapabase=argentina9252.plot(facecolor='pink',edgecolor='black',linewidth=0.5,figsize=(5,5))
ciudades9252.plot(marker='+',color='green', markersize=16,ax=mapabase)
rios9252.plot(edgecolor='blue',linewidth=0.5,ax=mapabase)
# Out:
# <Axes: >

# %%
alemania_coordenada=[52.52437, 13.41053]

# %%
import folium
m=ciudades4839.explore(location=alemania_coordenada,zoom_start=5,tiles='cartoDB positron',color='pink', name="cities")

m=rios4839.explore(m=m,color='blue',name="rivers")

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21bbc376d1f44490a2643ffc59139758 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21bbc376d1f44490a2643ffc59139758&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21bbc376d1f44490a2643ffc59139758 = L.map(
#                 &quot;map_21bbc376d1f44490a2643ffc59139758&quot;,
#                 {
#                     center: [52.52437, 13.41053],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_21bbc376d1f44490a2643ffc59139758);
#
#
#
#
#
#             var tile_layer_6d6a945d22efab810ab93064afbdef3d = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_21bbc376d1f44490a2643ffc59139758);
#
#
#         function geo_json_24d3117f27bba313560ac146438bb6cc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;pink&quot;, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_24d3117f27bba313560ac146438bb6cc_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_24d3117f27bba313560ac146438bb6cc_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_24d3117f27bba313560ac146438bb6cc_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_24d3117f27bba313560ac146438bb6cc_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_24d3117f27bba313560ac146438bb6cc.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_24d3117f27bba313560ac146438bb6cc_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_24d3117f27bba313560ac146438bb6cc = L.geoJson(null, {
#                 onEachFeature: geo_json_24d3117f27bba313560ac146438bb6cc_onEachFeature,
#
#                 style: geo_json_24d3117f27bba313560ac146438bb6cc_styler,
#                 pointToLayer: geo_json_24d3117f27bba313560ac146438bb6cc_pointToLayer
#         });
#
#         function geo_json_24d3117f27bba313560ac146438bb6cc_add (data) {
#             geo_json_24d3117f27bba313560ac146438bb6cc
#                 .addData(data)
#                 .addTo(map_21bbc376d1f44490a2643ffc59139758);
#         }
#             geo_json_24d3117f27bba313560ac146438bb6cc_add({&quot;bbox&quot;: [6.775304317474365, 48.140975952148445, 13.705357551574707, 53.57112121582032], &quot;features&quot;: [{&quot;bbox&quot;: [10.027606010437012, 53.57112121582032, 10.027606010437012, 53.57112121582032], &quot;geometry&quot;: {&quot;coordinates&quot;: [10.0276

# %%
import matplotlib.pyplot as plt

mapabase=alemania4839.plot(facecolor='pink',edgecolor='black',linewidth=0.5,figsize=(5,5))
mapa2=ciudades4839.plot(marker='+',color='green', markersize=16,ax=mapabase)
mapa3=rios4839.plot(edgecolor='blue',linewidth=0.5,ax=mapabase)

plt.savefig(os.path.join("figures",'mapa3.jpg'))

# %%
countries.to_file(os.path.join("maps","worldMaps.gpkg"), layer='countries', driver="GPKG")
cities.to_file(os.path.join("maps","worldMaps.gpkg"), layer='cities', driver="GPKG")
rivers.to_file(os.path.join("maps","worldMaps.gpkg"), layer='rivers', driver="GPKG")

# %%
worldMaps='https://github.com/Romina300/simpleplot/raw/main/maps/worldMaps.gpkg'

# %%
from  fiona import listlayers

listlayers(worldMaps)
# Out:
# ['countries', 'cities', 'rivers']

# %%
countries=gpd.read_file(worldMaps,layer='countries')
cities=gpd.read_file(worldMaps,layer='cities')
rivers=gpd.read_file(worldMaps,layer='rivers')

# %%
import os

alemania4839.to_file(os.path.join("maps","alemania4839","alemaniaMaps4839.gpkg"), layer='country', driver="GPKG")
ciudades4839.to_file(os.path.join("maps","alemania4839","alemaniaMaps4839.gpkg"), layer='cities', driver="GPKG")
rios4839.to_file(os.path.join("maps","alemania4839","alemaniaMaps4839.gpkg"), layer='rivers', driver="GPKG")

# %%
link_alemaniaMaps4839='https://github.com/Romina300/simpleplot/raw/main/maps/alemania4839/alemaniaMaps4839.gpkg'

# %%
from  fiona import listlayers

listlayers(link_alemaniaMaps4839)
# Out:
# ['country', 'cities', 'rivers']

# %%
#countries.to_file(os.path.join("maps","worldMaps.gpkg"), layer='countries', driver="GPKG")
#cities.to_file(os.path.join("maps","worldMaps.gpkg"), layer='cities', driver="GPKG")
#rivers.to_file(os.path.join("maps","worldMaps.gpkg"), layer='rivers', driver="GPKG")
