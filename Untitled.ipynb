# %% [markdown]
# # Exercise:
# lo hice clickeando el teclado y heading
# 1. Create a repo: **simpleplot** done
# 2. Clone that repo to your computer. done
# 3. Put the same **rar** files we used at the begining (countries, cities, rivers). done
# 4. Keep the maps for one country.
# 5. Find the right CRS for the country, and make sure the other maps share the same one.
# 6. **Plot the projected** maps like this:
#
#    7.1 Each one independently.
#
#    7.2 All together
#
#    7.3 All together interactively
# 8. Save the NON interactive map (6.2) as an image.
# 9. Save the three reprojected maps  into **one geopackage** file.
# 10. Get the link for the geopackage and make sure it is working well.

# %%
import os, geopandas as gpd

countries=gpd.read_file(os.path.join("maps","World_Countries","World_Countries.shp"))

# %%
rivers=gpd.read_file(os.path.join("maps","World_Hydrography","World_Hydrography.shp"))
cities=gpd.read_file(os.path.join("maps","World_Cities","World_Cities.shp"))

# %%
countries.columns
# Out:
# Index(['COUNTRY', 'geometry'], dtype='object')

# %%
cities.columns
# Out:
# Index(['NAME', 'COUNTRY', 'CAPITAL', 'geometry'], dtype='object')

# %%
cities.head()
# Out:
#                NAME COUNTRY CAPITAL                    geometry
# 0          Murmansk  Russia       N   POINT (33.08604 68.96355)
# 1       Arkhangelsk  Russia       N   POINT (40.64616 64.52067)
# 2  Saint Petersburg  Russia       N   POINT (30.45333 59.95189)
# 3           Magadan  Russia       N  POINT (150.78001 59.57100)
# 4             Perm'  Russia       N   POINT (56.23246 58.00024)

# %%
#asegurándo que tengan los  mismos crs

# %%
countries.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
rivers.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
cities.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
base = countries.plot(facecolor="pink", edgecolor='black', linewidth=0.1,figsize=(12,12))
cities.plot(marker='.', color='brown', markersize=1,alpha=0.9,
            ax=base) # on top of..
rivers.plot(edgecolor='blue', linewidth=0.4,
            ax=base)# on top of..
# Out:
# <Axes: >

# %%
import folium

m= cities.explore(color="red",name="cities")

m=rivers.explore(m=m, color="blue", name="rivers")

folium.LayerControl().add_to(m)


m

#mapa_interactivo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
alemania=countries[countries.COUNTRY=='Germany']

alemania.plot()
# Out:
# <Axes: >

# %%
ciudades_alemania=cities[cities.COUNTRY=='Germany']

ciudades_alemania.plot()
# Out:
# <Axes: >

# %%
rivers.head()
# Out:
#         NAME  SYSTEM                                           geometry
# 0      Aldan    Lena  LINESTRING (124.00678 56.47258, 123.25956 56.6...
# 1     Amazon  Amazon  MULTILINESTRING ((-61.27730 -3.60706, -60.6846...
# 2  Amu Darya     NaN  LINESTRING (73.98818 37.49952, 73.52595 37.528...
# 3       Amur     NaN  LINESTRING (122.63956 49.99730, 120.47874 49.2...
# 4     Angara     NaN  LINESTRING (105.07841 51.93053, 103.92959 51.7...

# %%
rios_alemania=gpd.clip(gdf=rivers, mask=alemania)

rios_alemania.plot()
# Out:
# <Axes: >

# %%
mapabase=alemania.plot(facecolor="pink",edgecolor="brown",linewidth=0.7,figsize=(5,5))

ciudades_alemania.plot(marker='+',color='red',markersize=15,ax=mapabase)
rios_alemania.plot(edgecolor='blue',linewidth=0.5,ax=mapabase)

#base = alemania.plot(facecolor="greenyellow", edgecolor='black', linewidth=0.4,figsize=(5,5))
#cities_brazil.plot(marker='+', color='red', markersize=15,ax=base)
#rivers_brazil.plot(edgecolor='blue', linewidth=0.5,ax=base)
# Out:
# <Axes: >

# %%
alemania.crs.axis_info
# Out:
# [Axis(name=Geodetic latitude, abbrev=Lat, direction=north, unit_auth_code=EPSG, unit_code=9122, unit_name=degree),
#  Axis(name=Geodetic longitude, abbrev=Lon, direction=east, unit_auth_code=EPSG, unit_code=9122, unit_name=degree)]

# %%
alemania.centroid
# Out:
# C:\Users\Edgar Ramos Castro\AppData\Local\Temp\ipykernel_16968\3730990436.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   alemania.centroid
# 87    POINT (10.39365 51.10656)
# dtype: geometry

# %%
alemania.to_crs(4839).crs.axis_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 alemania.to_crs(4839).crs.axis_info
#
# NameError: name 'alemania' is not defined

# %%
alemania.to_crs(4839).centroid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 alemania.to_crs(4839).centroid
#
# NameError: name 'alemania' is not defined

# %%
mapabase4839=alemania.to_crs(4839).plot()

alemania.to_crs(4839).centroid.plot(color='pink',ax=mapabase4839)
# Out:
# <Axes: >

# %%
alemania4839=alemania.to_crs(4839)
ciudades_alemania=cities[cities.COUNTRY=='Germany']
ciudades4839=ciudades_alemania.to_crs(alemania4839.crs)

rios4839=rivers.to_crs(alemania4839.crs)
rios4839=gpd.clip(gdf=rios4839, mask=alemania4839)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 alemania4839=alemania.to_crs(4839)
#       2 ciudades_alemania=cities[cities.COUNTRY=='Germany']
#       3 ciudades4839=ciudades_alemania.to_crs(alemania4839.crs)
#
# NameError: name 'alemania' is not defined

# %%
mapabase=alemania4839.plot(facecolor='pink',edgecolor='black',linewidth=0.5,figsize=(5,5))
ciudades4839.plot(marker='+',color='green', markersize=16,ax=mapabase)
rios4839.plot(edgecolor='blue',linewidth=0.5,ax=mapabase)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mapabase=alemania4839.plot(facecolor='pink',edgecolor='black',linewidth=0.5,figsize=(5,5))
#       2 ciudades4839.plot(marker='+',color='green', markersize=16,ax=mapabase)
#       3 rios4839.plot(edgecolor='blue',linewidth=0.5,ax=mapabase)
#
# NameError: name 'alemania4839' is not defined

# %%
alemania_coordenada=[52.52437, 13.41053]

# %%
m=ciudades4839.explore(location=alemania_coordenada,zoom_start=5,tiles='cartoDB positron',color='pink', name="cities")

m=rios4839.explore(m=m,color='blue',name="rivers")

folium.LayerControl().add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 m=ciudades4839.explore(location=alemania_coordenada,zoom_start=5,tiles='cartoDB positron',color='pink', name="cities")
#       3 m=rios4839.explore(m=m,color='blue',name="rivers")
#       5 folium.LayerControl().add_to(m)
#
# NameError: name 'ciudades4839' is not defined

# %%
import matplotlib.pyplot as plt

mapabase=alemania4839.plot(facecolor='pink',edgecolor='black',linewidth=0.5,figsize=(5,5))
mapa2=ciudades4839.plot(marker='+',color='green', markersize=16,ax=mapabase)
mapa3=rios4839.plot(edgecolor='blue',linewidth=0.5,ax=mapabase)

plt.savefig(os.path.join("figures",'mapa3.jpg'))
